# %%
import pandas as pd

import seaborn as sns
sns.set()
sns.set(style="darkgrid")


import numpy as np

# importing matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize']=(10,10)

df = pd.read_csv(r'C:\Users\deepa\OneDrive\Documents\Upgrad\DataSets\LendingClubCaseStudy\loans.csv')

# %%
df = df.dropna(axis=1)

# %%
##print(df)
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ... total_rec_prncp  \
# 0       36 months   10.65%       162.87     B        B2  ...         5000.00
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
print(df.isnull().sum())
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# pymnt_plan                 0
# url                        0
# purpose                    0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# total_acc                  0
# initial_list_status        0
# out_prncp                  0
# out_prncp_inv              0
# total_pymnt                0
# ...

# %%
df.dropna(thresh=0.95*len(df.columns))
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ... total_rec_prncp  \
# 0       36 months   10.65%       162.87     B        B2  ...         5000.00
# ...

# %%
df['StateandZipCd'] = df['zip_code'] + ', ' + df['addr_state']

df.drop(['zip_code','addr_state'], axis = 1)
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ... total_rec_int  \
# 0       36 months   10.65%       162.87     B        B2  ...        863.16
# ...

# %%
print(df)
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ... total_rec_int  \
# 0       36 months   10.65%       162.87     B        B2  ...        863.16
# ...

# %%
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %%
(df['loan_status'].value_counts().head(10) / len(df)).plot.bar()
# Out:
# <Axes: >

# %%
(df['int_rate'].value_counts() / len(df)).plot.line()
# Out:
# <Axes: >

# %%
df['grade'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: >

# %%
df['home_ownership'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: >

# %%
df['loan_amnt'].value_counts().sort_index().plot.line()
# Out:
# <Axes: >

# %%
df['annual_inc'].value_counts().sort_index().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
##Bivariate Analysis

# %%
df.plot.scatter(x='loan_status', y='loan_amnt')
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %%
dfnew = df.filter(['id','loan_status','loan_amnt','int_rate','grade','sub_grade', 'home_ownership','annual_inc','term','installment'], axis=1)

dfnew['int_rate'] = (dfnew['int_rate'].str.strip('%').astype(float))
##dfnew.plot.bar(stacked=True)
dfnew.columns
# Out:
# Index(['id', 'loan_status', 'loan_amnt', 'int_rate', 'grade', 'sub_grade',
#        'home_ownership', 'annual_inc', 'term', 'installment'],
#       dtype='object')

# %%
dfline = dfnew.groupby('loan_status').mean()[['loan_amnt']]
dfline.plot.line()
# Out:
# <Axes: xlabel='loan_status'>

# %%
dfline = dfnew.groupby('loan_status').mean()[['int_rate']]
dfline.plot.line()
# Out:
# <Axes: xlabel='loan_status'>

# %%
dfforline = dfnew.groupby('loan_status').mean()[['annual_inc', 'loan_amnt']]
dfforline.plot.line()
# Out:
# <Axes: xlabel='loan_status'>

# %%
##dfforline1 = df.groupby('loan_status').mean()[['term']]
##dfforline1.plot.line()
ax1 = dfnew.groupby(['loan_status'])['grade'].value_counts().unstack().plot(kind='bar',stacked = True)

# %%
ax1 = df.groupby(['loan_status'])['verification_status'].value_counts().unstack().plot(kind='bar',stacked = True)

# %%
df2 = dfnew[dfnew.loan_status.isin(dfnew.loan_status.value_counts().index)]

sns.boxplot(
    x='loan_status',
    y='int_rate',
    data=dfnew
)
# Out:
# <Axes: xlabel='loan_status', ylabel='int_rate'>

# %%
dfnewnew = dfnew.groupby(['loan_status', 'grade']).mean()[['annual_inc']]
dfnewnew.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='loan_status,grade'>

# %%
dfnewnew = dfnew.groupby(['loan_status', 'term']).mean()[['int_rate']]
dfnewnew.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='loan_status,term'>

# %%
dfnewnew = dfnew.groupby(['loan_status', 'home_ownership']).mean()[['int_rate']]
dfnewnew.plot.bar(stacked=True)
# Out:
# <Axes: xlabel='loan_status,home_ownership'>

# %%
df2 = dfnew[dfnew.loan_status.isin(dfnew.loan_status.value_counts().index)]

sns.boxplot(
    x='loan_status',
    y='loan_amnt',
    data=dfnew
)
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>
